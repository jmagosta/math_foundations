# %% [markdown]
# # Find extremes in a real valued function
#
# JMA Jan 2023

# %%
import math, sys
import numpy as np

from bokeh.plotting import figure, show
# from bokeh.layouts import column
# from bokeh.models import ColumnDataSource, FixedTicker, MultiLine, Grid, Plot, LinearAxis
from bokeh.io import output_notebook
# from bokeh import palettes
output_notebook()

# %%
def curious_function(x):
  return math.exp(-x) * pow(x,3)

# %%
xs = np.linspace(-2, 10)
f = np.vectorize(curious_function)

# %%
p = figure()
p.line(xs, f(xs))
show(p)
# Out:
#   <div id="e4595450-0fd6-4296-ac33-28e3a9f55958" data-root-id="p1302" style="display: contents;"></div>
